# %% [markdown]
# <a href="https://colab.research.google.com/github/irostylemina/gitstudy/blob/main/10%EC%A3%BC%EC%B0%A8_%EC%88%99%EC%A0%9C_2025163046_%EC%9E%84%EB%AF%B8%EB%82%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cell 1. p.11 계산기 더하기 기능

# %%
result = 0

def adder(num):
    global result
    result += num
    return result

print(adder(3))
print(adder(4))
# Out:
# 3
# 7

# %%
In[4]: print(adder(4))
In[5]: print(adder(5))
# Out:
# 11
# 16

# %% [markdown]
# # Cell 2. p.12 계산기 두 개

# %%
result1 = 0
result2 = 0

def adder1(num):
    global result1
    result1 += num
    return result1

def adder2(num):
    global result2
    result2 += num
    return result2

print(adder1(3))
print(adder1(4))
print(adder2(3))
print(adder2(7))
# Out:
# 3
# 7
# 3
# 10

# %% [markdown]
# # Cell 3. p.13 클래스 계산기

# %%
class Calculator:
    def __init__(self):
        self.result = 0

    def adder(self, num):
        self.result += num
        return self.result

cal1 = Calculator()
cal2 = Calculator()

print(cal1.adder(3))
print(cal1.adder(4))
print(cal2.adder(3))
print(cal2.adder(7))
# Out:
# 3
# 7
# 3
# 10

# %% [markdown]
# # Cell 4. p.15 클래스 변수

# %%
class Service:
    secret = "지구는 4006년에 멸망한다."

an = Service()
print(an.secret)
# Out:
# 지구는 4006년에 멸망한다.

# %% [markdown]
# # Cell 5. p.16 클래스 변수 공유

# %%
Service.secret
'지구는 4006년에 멸망한다.'

Service.secret = '지구가 4006년에 멸망한다는 사실은 뻥이다.'

print(an.secret)
# Out:
# 지구가 4006년에 멸망한다는 사실은 뻥이다.

# %% [markdown]
# # Cell 6. p.17 메서드

# %%
class Service:
    secret = "지구는 4006년에 멸망한다."

    def sum(self, a, b):
        result = a + b
        print("%s + %s = %s이다." % (a, b, result))

an = Service()
an.sum(1, 1)
# Out:
# 1 + 1 = 2이다.

# %% [markdown]
# # Cell 7. p.19 객체 변수

# %%
class Service:
    secret = "지구는 4006년에 멸망한다."

    def setname(self, name):
        self.name = name

    def sum(self, a, b):
        result = a + b
        print("%s님, %s + %s = %s입니다." % (self.name, a, b, result))

an = Service()
an.setname("박달도사")
an.sum(1, 1)
# Out:
# 박달도사님, 1 + 1 = 2입니다.

# %% [markdown]
# # Cell 8. p.20 클래스 변수와 객체 변수

# %%
kim = Service()
park = Service()

kim.name = "김정보"
park.name = "박융합"

print(kim.name)
print(park.name)

kim.secret = "비밀은 없다"
print(park.secret)
print(kim.secret)

Service.secret
# Out:
# 김정보
# 박융합
# 지구는 4006년에 멸망한다.
# 비밀은 없다
# '지구는 4006년에 멸망한다.'

# %% [markdown]
# # Cell 9. p.21 setname 호출 안 한 경우 오류 확인

# %%
lee = Service()
lee.sum(1, 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_561/1617489729.py in <cell line: 0>()
#       1 lee = Service()
# ----> 2 lee.sum(1, 1)
#
# /tmp/ipykernel_561/4281062951.py in sum(self, a, b)
#       7     def sum(self, a, b):
#       8         result = a + b
# ----> 9         print("%s님, %s + %s = %s입니다." % (self.name, a, b, result))
#      10
#      11 an = Service()
#
# AttributeError: 'Service' object has no attribute 'name'

# %% [markdown]
# # Cell 10. p.22 init

# %%
class Service:
    secret = "지구는 4006년에 멸망한다."

    def __init__(self, name):
        self.name = name

    def sum(self, a, b):
        result = a + b
        print("%s님, %s + %s = %s입니다." % (self.name, a, b, result))

an = Service("박달도사")
an.sum(1, 1)
# Out:
# 박달도사님, 1 + 1 = 2입니다.

# %% [markdown]
# # Cell 11. p.24 사칙연산 클래스 껍데기

# %%
class FourCal:
    pass

a = FourCal()
type(a)
# Out:
# __main__.FourCal

# %% [markdown]
# # Cell 12. p.25 데이터 세팅

# %%
class FourCal:
    def setdata(self, first, second):
        self.first = first
        self.second = second

a = FourCal()
a.setdata(4, 2)

print(a.first)
print(a.second)
# Out:
# 4
# 2

# %% [markdown]
# # Cell 13. p.26 더하기

# %%
class FourCal:
    def setdata(self, first, second):
        self.first = first
        self.second = second

    def sum(self):
        result = self.first + self.second
        return result

a = FourCal()
a.setdata(4, 2)

print(a.sum())
# Out:
# 6

# %% [markdown]
# # Cell 14. p.27 사칙연산 전체

# %%
class FourCal:
    def setdata(self, first, second):
        self.first = first
        self.second = second

    def sum(self):
        result = self.first + self.second
        return result

    def mul(self):
        result = self.first * self.second
        return result

    def sub(self):
        result = self.first - self.second
        return result

    def div(self):
        result = self.first / self.second
        return result

a = FourCal()
b = FourCal()

a.setdata(4, 2)
b.setdata(3, 7)

print(a.sum())
print(a.mul())
print(a.sub())
print(a.div())
print(b.sub())
# Out:
# 6
# 8
# 2
# 2.0
# -4

# %% [markdown]
# # Cell 15. p.30 주사위 게임 — 순차적 프로그래밍

# %%
import random

player1_dice = []
player2_dice = []

for i in range(3):
    player1_dice.append(random.randint(1, 6))
    player2_dice.append(random.randint(1, 6))

print("Player 1 rolled" + str(player1_dice))
print("Player 2 rolled" + str(player2_dice))

if sum(player1_dice) == sum(player2_dice):
    print("Draw")
elif sum(player1_dice) > sum(player2_dice):
    print("Player 1 wins")
else:
    print("Player 2 wins")
# Out:
# Player 1 rolled[4, 4, 2]
# Player 2 rolled[3, 4, 4]
# Player 2 wins

# %% [markdown]
# # Cell 16. p.31 주사위 게임 — OOP

# %%
from random import randint

class Player:
    def __init__(self):
        self.dice = []

    def roll(self):
        self.dice = []
        for i in range(3):
            self.dice.append(randint(1, 6))

    def get_dice(self):
        return self.dice

player1 = Player()
player2 = Player()

player1.roll()
player2.roll()

print("Player 1 rolled" + str(player1.get_dice()))
print("Player 2 rolled" + str(player2.get_dice()))

if sum(player1.get_dice()) == sum(player2.get_dice()):
    print("Draw!")
elif sum(player1.get_dice()) > sum(player2.get_dice()):
    print("Player 1 wins!")
else:
    print("Player 2 wins!")
# Out:
# Player 1 rolled[1, 5, 1]
# Player 2 rolled[1, 4, 2]
# Draw!
